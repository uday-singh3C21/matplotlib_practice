# %% [markdown]
# # scatter plot graph

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

# %%
df_google_play_store_apps=pd.read_csv(r"C:\Users\USER\Downloads\Case+Study+Notebook\Case Study Notebook\googleplaystore_v2.csv")
df_google_play_store_apps.shape
# Out:
# (10841, 13)

# %%
df_google_play_store_apps=pd.read_csv(r"C:\Users\USER\Downloads\Case+Study+Notebook\Case Study Notebook\googleplaystore_v2.csv",nrows=1000)
df_google_play_store_apps.shape
# Out:
# (1000, 13)

# %%
df_google_play_store_apps
# Out:
#                                                   App           Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                 Coloring book moana     ART_AND_DESIGN
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                               Sketch - Draw & Paint     ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# ..                                                ...                ...
# 95  All of the parking lot - National Park applica...  AUTO_AND_VEHICLES
# 96               Inquiry Fines and Debits of Vehicles  AUTO_AND_VEHICLES
# 97                                        Gas Station  AUTO_AND_VEHICLES
# 98                         Hush - Beauty for Everyone             BEAUTY
# 99                     ipsy: Makeup, Beauty, and Tips             BEAUTY
#
#     Rating  Reviews     Size     Installs  Type  Price Content Rating  \
# ...

# %%
x=df_google_play_store_apps["Rating"]
y=df_google_play_store_apps["Reviews"]
plt.scatter(x,y)

# %%
plt.scatter(x,y)
plt.title("google_play_store_apps")
plt.xlabel("Rating")
plt.ylabel("Reviews")
# Out:
# Text(0, 0.5, 'Reviews')

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y,c='r')
plt.title("google_play_store_apps")
plt.xlabel("Rating")
plt.ylabel("Reviews")
# Out:
# Text(0, 0.5, 'Reviews')

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y,c='r')
plt.scatter(x,df_google_play_store_apps["Installs"],c='y')
plt.title("google_play_store_apps")
plt.xlabel("Rating")
plt.ylabel("Reviews")
# Out:
# Text(0, 0.5, 'Reviews')
